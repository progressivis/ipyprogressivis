# %%
import json
from ipyprogressivis.csv_sniffer.callbacks import *
from ipyprogressivis.csv_sniffer.backend import CSVSnifferDF
from ipyprogressivis.ipyfuncs import *
with open("/tmp/csv_sniffer_demo.json") as f:
    bulk = json.load(f)
restored = restore(bulk, globals(), None)
update_backend(restored)
restored.widget
