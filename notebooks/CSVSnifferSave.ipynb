# %%
from ipyprogressivis.csv_sniffer.sniffer import *
proxy = sniffer("https://www.aviz.fr/nyc-taxi/yellow_tripdata_2015-01.csv.bz2")
proxy.widget

# %%
import json
bulk = proxy.dump()
with open("/tmp/csv_sniffer_demo.json", "w") as f:
    json.dump(bulk, f)
