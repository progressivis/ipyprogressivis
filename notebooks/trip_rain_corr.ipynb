# %% [markdown]
# <button data-commandLinker-command="progressivis:cleanup_and_run" data-commandlinker-args='{"index": 1}' href="#" class='progressivis-cleanup-and-run-btn'>Run ProgressiVis</button>

# %%
from ipyprogressivis.widgets.chaining.constructor import Constructor
from ipyprogressivis.widgets.chaining.utils import create_root, get_header
from ipyprogressivis.widgets.chaining.custom import *
# ***************************************************************************************
# WARNING: This cell must only be executed using the 'Run ProgressiVis' button above.
# Do not execute it in any other way, as the result will not be as expected.
# For the same reason do not copy/paste the contents of this cell to execute it elsewhere
# ***************************************************************************************
header = get_header()
display(header.talker)
display(header.backup)
_ = header.constructor
with header.modules_out:
    display(header.board)
with header.widgets_out:
    display(header.manager)
header.talker.labcommand("notebook:hide-cell-code")
# %reload_ext ipyprogressivis.magics
create_root(header.backup)
# Out:
# Talker()
# BackupWidget()

# %%
# progressivis-snippet
import numpy as np

@register_function
def nan_to_zero(x: float) -> float:
    return 0. if np.isnan(x) else x

# %% [markdown]
# ## root

# %%
# do not run this cell
display(header.constructor)
header.constructor.start_scheduler()
header.talker.labcommand('notebook:hide-cell-code')
# Out:
# Constructor(children=(IntProgress(value=0, description='Starting ProgressiVis ...', max=2, style=ProgressStyle…
# Starting scheduler
# # Scheduler added module(s): ['sink_1', 'variable_1']
# # Scheduler added module(s): ['data_shape_1', 'data_shape_2', 'sink_6', 'sink_7']
# # Scheduler deleted module(s): {'sink_6', 'data_shape_1'}
# # Scheduler deleted module(s): {'sink_7', 'data_shape_2'}
# # Scheduler added module(s): ['data_shape_1', 'sink_7']
# # Scheduler added module(s): ['data_shape_2', 'sink_8']
# # Scheduler deleted module(s): {'sink_7', 'data_shape_1'}
# # Scheduler deleted module(s): {'sink_8', 'data_shape_2'}
# # Scheduler added module(s): ['data_shape_1', 'sink_8']
# # Scheduler added module(s): ['data_shape_2', 'sink_9']
# # Scheduler deleted module(s): {'sink_8', 'data_shape_1'}
# # Scheduler deleted module(s): {'data_shape_2', 'sink_9'}

# %% [markdown]
# ## Weather

# %%
Constructor.widget('Weather', 0).run()
# Out:
# NodeCarrier(children=(HBox(children=(Button(button_style='danger', disabled=True, icon='trash', style=ButtonSt…

# %% [markdown]
# ## Fixing T

# %%
Constructor.widget('Fixing T', 0).run()
# Out:
# NodeCarrier(children=(HBox(children=(Button(button_style='danger', disabled=True, icon='trash', style=ButtonSt…

# %% [markdown]
# ## Taxis

# %%
Constructor.widget('Taxis', 0).run()
# Out:
# NodeCarrier(children=(HBox(children=(Button(button_style='danger', disabled=True, icon='trash', style=ButtonSt…

# %% [markdown]
# ## Group days

# %%
Constructor.widget('Group days', 0).run()
# Out:
# NodeCarrier(children=(HBox(children=(Button(button_style='danger', disabled=True, icon='trash', style=ButtonSt…

# %% [markdown]
# ## Trips cnt

# %%
Constructor.widget('Trips cnt', 0).run()
# Out:
# Late input_dtypes <function AggregateW.initialize at 0x71f3e6407e20>
# NodeCarrier(children=(HBox(children=(Button(button_style='danger', disabled=True, icon='trash', style=ButtonSt…

# %% [markdown]
# ## Join

# %%
Constructor.widget('Join', 0).run()
# Out:
# Late input_dtypes <function JoinW.initialize at 0x71f3e6415d20>
# NodeCarrier(children=(HBox(children=(Button(button_style='danger', disabled=True, icon='trash', style=ButtonSt…

# %% [markdown]
# ## Corr

# %%
Constructor.widget('Corr', 0).run()
# Out:
# Late input_dtypes <function CorrelationW.initialize at 0x71f3e4efe820>
# NodeCarrier(children=(HBox(children=(Button(button_style='danger', disabled=True, icon='trash', style=ButtonSt…
