# %%
from ipyprogressivis.widgets.scatterplot import Scatterplot
sc = Scatterplot(enable_centroids=True)
sc.to_hide = ["historyGrp"]
import warnings
warnings.filterwarnings('ignore')

# %%
from progressivis.cluster import MBKMeans, MBKMeansFilter
from progressivis.vis import MCScatterPlot
from progressivis.datasets import get_dataset
from progressivis.stats.api import RandomPTable
import numpy as np
from progressivis.datasets.random import generate_random_multivariate_normal_csv as gen_csv
from progressivis.stats.blobs_table import BlobsPTable, MVBlobsPTable

MULTIVARIATE_NORMAL = True
n_clusters = 7
if not MULTIVARIATE_NORMAL: # simple isotropic blobs (using scikit-learn make_blobs)
    centers = [(0.1, 0.3), (0.7, 0.5), (-0.4, -0.3)]
    data = BlobsPTable(columns=['_0', '_1'],  centers=centers, cluster_std=0.2, rows=1000_000)
else: # i.e. control each cluster's covariance matrix (using numpy.random.multivariate_normal)
    print("MULTIVARIATE_NORMAL")
    means = [0.1, 0.3], [0.7, 0.5], [-0.4, -0.3]
    covs = [[0.01, 0], [0, 0.09]], [[0.04, 0], [0, 0.01]], [[0.09, 0.04], [0.04, 0.02]]
    data = MVBlobsPTable(columns=['_0', '_1'], means=means, covs=covs, rows=1000_000)
classes = []
mbkmeans = MBKMeans(n_clusters=n_clusters, batch_size=100, is_input=False)
mbkmeans.create_dependent_modules(data)
for i in range(n_clusters):
    cname = f"k{i}"
    filt = MBKMeansFilter(i)
    filt.create_dependent_modules(mbkmeans, data, 'result')
    classes.append({'name': cname, 'x_column': '_0',
                    'y_column': '_1', 'sample': mbkmeans if i==0 else None,
                    'sample_slot': 'result',
                    'input_module': filt, 'input_slot': 'result'})    

sp = MCScatterPlot(classes=classes, queryable=False)
sp.create_dependent_modules()
sp.move_point = mbkmeans.dep.moved_center # for input management
# Create the dashboard object
show = sc.link_module(sp)
sp.scheduler.task_start();
# Out:
# MULTIVARIATE_NORMAL
# Starting scheduler
# # Scheduler added module(s): ['filter_mod_1', 'filter_mod_2', 'filter_mod_3', 'filter_mod_4', 'filter_mod_5', 'filter_mod_6', 'filter_mod_7', 'max_1', 'max_2', 'max_3', 'max_4', 'max_5', 'max_6', 'max_7', 'mbk_means_1', 'mbk_means_filter_1', 'mbk_means_filter_2', 'mbk_means_filter_3', 'mbk_means_filter_4', 'mbk_means_filter_5', 'mbk_means_filter_6', 'mbk_means_filter_7', 'mc_histogram2_d_1', 'mc_histogram2_d_2', 'mc_histogram2_d_3', 'mc_histogram2_d_4', 'mc_histogram2_d_5', 'mc_histogram2_d_6', 'mc_histogram2_d_7', 'mc_scatter_plot_1', 'min_1', 'min_2', 'min_3', 'min_4', 'min_5', 'min_6', 'min_7', 'mv_blobs_p_table_1', 'variable_1']

# %%
sc
# Out:
# Scatterplot(to_hide=['historyGrp'])

# %% [markdown]
# <button data-commandLinker-command="notebook:restart-run-all" href="#" >Restart Kernel and Run All Cells…</button>
